# %%
# https://towardsdatascience.com/time-series-forecasting-predicting-stock-prices-using-facebooks-prophet-model-9ee1657132b5
# https://colab.research.google.com/drive/1l4bbQkcjn7Oy-SMnaLnlobQ4sorgHB2S?usp=sharing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
#goal = "BCH-USD"
#data = web.DataReader(goal, 'yahoo')

data = pd.read_csv("data/BitcoinCash.csv")

# %%
data.tail()
# Out:
#                Date    Open    High     Low   Close     Volume Market Cap
# 1167  jul. 27, 2017   417,1  460,97  367,78  385,48    533.207          0
# 1168  jul. 26, 2017  407,08  486,16  321,79  365,82  1.784.640          0
# 1169  jul. 25, 2017  441,35  541,66  338,09   406,9    524.908          0
# 1170  jul. 24, 2017  412,58  578,89  409,21   440,7    190.952          0
# 1171  jul. 23, 2017  555,89  578,97  411,78  413,06  85.013,10          0

# %%
data.describe()
# Out:
#                 Date    Open    High    Low   Close       Volume Market Cap
# count           1172    1172    1172   1172    1172         1172       1172
# unique          1172    1162    1159   1156    1163         1172       1164
# top     Sep 20, 2018  326,59  287,01  466,3  224,02  538.528.000          0
# freq               1       2       2      2       2            1          9

# %%
data.reset_index(level=0, inplace=True)

# %%
data.head()
# Out:
#    index          Date    Open    High     Low   Close         Volume  \
# 0      0  Oct 06, 2020  222,33  229,11  218,02  220,44  1.414.548.623
# 1      1  Oct 05, 2020  221,77  223,08  219,88  222,39    852.614.530
# 2      2  Oct 04, 2020  219,73  223,26  218,12  221,81    891.670.097
# 3      3  Oct 03, 2020  220,22  221,68  219,27  219,74    785.032.604
# 4      4  Oct 02, 2020  228,08  228,34  214,63  220,19  1.430.714.877
#
#       Market Cap
# 0  4.086.477.621
# 1  4.122.271.868
# 2  4.111.338.358
# 3  4.072.888.492
# 4  4.080.960.314

# %%
# Select only the important features i.e. the date and price
data = data[["Date","Close"]] # select Date and Price
# Rename the features: These names are NEEDED for the model fitting
data = data.rename(columns = {"Date":"ds","Close":"y"}) #renaming the columns of the dataset
data.head(5)
# Out:
#              ds       y
# 0  Oct 06, 2020  220,44
# 1  Oct 05, 2020  222,39
# 2  Oct 04, 2020  221,81
# 3  Oct 03, 2020  219,74
# 4  Oct 02, 2020  220,19

# %%
def stringToFloat(value):
    if(len(value.split(',')) == 1): 
        value = value.replace(",", ".")
        return float(value)
    else:
       splitedValue = value.split(',')
       valueComma = splitedValue[-1]
       splitedValue = splitedValue[:len(splitedValue)-1]
       newValue = ""
       for value in splitedValue:
           newValue += value
       newValue += "," + valueComma
       newValue = float(newValue.replace(",", "."))
       return newValue

data['y'] = data['y'].apply(stringToFloat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-6618d63efb1f> in <module>
#      14        return newValue
#      15
# ---> 16 data['y'] = data['y'].apply(stringToFloat)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-130-6618d63efb1f> in stringToFloat(value)
#      11            newValue += value
#      12        newValue += "," + valueComma
# ---> 13        newValue = float(newValue.replace(",", "."))
#      14        return newValue
#      15
#
# ValueError: could not convert string to float: '1.092.13'

# %%
data.head(5)
# Out:
#              ds       y
# 0  Oct 06, 2020  220,44
# 1  Oct 05, 2020  222,39
# 2  Oct 04, 2020  221,81
# 3  Oct 03, 2020  219,74
# 4  Oct 02, 2020  220,19

# %%
from fbprophet import Prophet
m = Prophet(daily_seasonality = True) # the Prophet class (model)
m.fit(data) # fit the model using all data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.092.13"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-7fc44a1b74af> in <module>
#       1 from fbprophet import Prophet
#       2 m = Prophet(daily_seasonality = True) # the Prophet class (model)
# ----> 3 m.fit(data) # fit the model using all data
#
# ~/.local/lib/python3.6/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1109         self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
#    1110
# -> 1111         history = self.setup_dataframe(history, initialize_scales=True)
#    1112         self.history = history
#    1113         self.set_auto_seasonalities()
#
# ~/.local/lib/python3.6/site-packages/fbprophet/forecaster.py in setup_dataframe(self, df, initialize_scales)
#     255         """
#     256         if 'y' in df:  # 'y' will be in training data
# --> 257             df['y'] = pd.to_numeric(df['y'])
#     258             if np.isinf(df['y'].values).any():
#     259                 raise ValueError('Found infinity in column y.')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.092.13" at position 850

# %%
future = m.make_future_dataframe(periods=365) #we need to specify the number of days in future
prediction = m.predict(future)
m.plot(prediction)
plt.title("Prediction of the " + goal + " Price using the Prophet")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-122-850efb96fc1b> in <module>
#       1 future = m.make_future_dataframe(periods=365) #we need to specify the number of days in future
# ----> 2 prediction = m.predict(future)
#       3 m.plot(prediction)
#       4 plt.title("Prediction of the " + goal + " Price using the Prophet")
#       5 plt.xlabel("Date")
#
# ~/.local/lib/python3.6/site-packages/fbprophet/forecaster.py in predict(self, df)
#    1190         """
#    1191         if self.history is None:
# -> 1192             raise Exception('Model has not been fit.')
#    1193
#    1194         if df is None:
#
# Exception: Model has not been fit.

# %%
# Plot the trend, weekly, seasonally, yearly and daily components

m.plot_components(prediction)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-a80917d57a93> in <module>
#       1 # Plot the trend, weekly, seasonally, yearly and daily components
#       2
# ----> 3 m.plot_components(prediction)
#       4 plt.show()
#
# ~/.local/lib/python3.6/site-packages/fbprophet/forecaster.py in plot_components(self, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#    1624             m=self, fcst=fcst, uncertainty=uncertainty, plot_cap=plot_cap,
#    1625             weekly_start=weekly_start, yearly_start=yearly_start,
# -> 1626             figsize=figsize
#    1627         )
#
# ~/.local/lib/python3.6/site-packages/fbprophet/plot.py in plot_components(m, fcst, uncertainty, plot_cap, weekly_start, yearly_start, figsize)
#     151     multiplicative_axes = []
#     152
# --> 153     dt = m.history['ds'].diff()
#     154     min_dt = dt.iloc[dt.values.nonzero()[0]].min()
#     155
#
# TypeError: 'NoneType' object is not subscriptable

# %%
prediction.shape
# Out:
# (1533, 22)

# %%
future_prediction = prediction[-365:]

# %%
future_prediction.head()
# Out:
#              ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 
ekly  weekly_lower  weekly_upper      yearly  yearly_lower  \
# 1168  ... -9.198107     -9.198107     -9.198107 -159.639718   -159.639718
# 1169  ...  1.281680      1.281680      1.281680 -169.655739   -169.655739
# 1170  ...  7.432476      7.432476      7.432476 -180.011746   -180.011746
# 1171  ...  4.763730      4.763730      4.763730 -190.537871   -190.537871
# 1172  ... -0.923969     -0.923969     -0.923969 -201.046744   -201.046744
# 1173  ... -3.528690     -3.528690     -3.528690 -211.337634   -211.337634
# 1174  ...  0.172879      0.172879      0.172879 -221.201053   -221.201053
# 1175  ... -9.198107     -9.198107     -9.198107 -230.423724   -230.423724
# 1176  ...  1.281680      1.281680      1.281680 -238.793783   -238.793783
# 1177  ...  7.432476      7.432476      7.432476 -246.106079   -246.106079
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 1168   -159.639718                   0.0                         0.0
# 1169   -169.655739                   0.0                         0.0
# 1170   -180.011746                   0.0                         0.0
# 1171   -190.537871                   0.0                         0.0
# 1172   -201.046744                   0.0                         0.0
# 1173   -211.337634                   0.0                         0.0
# 1174   -221.201053                   0.0                         0.0
# 1175   -230.423724                   0.0                         0.0
# 1176   -238.793783                   0.0                         0.0
# 1177   -246.106079                   0.0                         0.0
#
#       multiplicative_terms_upper       yhat
# 1168                         0.0  60.612420
# 1169                         0.0  60.888377
# 1170                         0.0  56.495359
# 1171                         0.0  43.112680
# 1172                         0.0  26.728300
# 1173                         0.0  13.644882
# 1174                         0.0   7.295224
# 1175                         0.0 -11.486240
# 1176                         0.0  -9.564320
# 1177                         0.0 -10.913628
#
# [10 rows x 22 columns]

# %%
future_prediction.yhat.values[:50]
# Out:
# array([ 60.61241973,  60.88837734,  56.49535944,  43.11268039,
#         26.72830023,  13.64488154,   7.29522397, -11.48624036,
#         -9.56431975, -10.91362768, -19.83155832, -30.34146632,
#        -36.1872821 , -34.01785673, -43.11434615, -30.48908027,
#        -20.2932798 , -17.02640085, -14.93498283,  -8.0023311 ,
#          6.87255491,  10.1533685 ,  34.57361255,  55.73493719,
#         68.90376948,  79.61821202,  93.70373557, 114.09912066,
#        121.13908566, 147.46490821, 168.6254407 , 179.87552042,
#        186.78370229, 195.24781369, 208.31978358, 206.48620473,
#        222.57598017, 232.35752048, 231.33257902, 225.33875753,
#        220.55930126, 220.34176869, 205.47217607, 209.07611563,
#        207.2094637 , 195.64591435, 180.47351407, 168.09895193,
#        162.06131352, 143.30200808])

# %%
plt.plot(future_prediction.ds.values, future_prediction.yhat.values)
plt.title("Prediction of the " + goal + " Price using the Prophet")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()

# %%
future_prediction.yhat.values[:364]
# Out:
# array([ 60.61241973,  60.88837734,  56.49535944,  43.11268039,
#         26.72830023,  13.64488154,   7.29522397, -11.48624036,
#         -9.56431975, -10.91362768, -19.83155832, -30.34146632,
#        -36.1872821 , -34.01785673, -43.11434615, -30.48908027,
